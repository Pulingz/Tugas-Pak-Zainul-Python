# %%
mobil=20
print(mobil)
motor=30
print(motor)
# Out:
# 20
# 30

# %%
mobil=50
motor=60
mobil+=motor 
print(mobil)
# Out:
# 110

# %%
mobil=110
motor=150
mobil-=motor
print(motor)
# Out:
# 150

# %%
mobil=200
motor=300
mobil*=motor
print(mobil)
# Out:
# 60000

# %%
mobil=900
motor=500
mobil/=motor
print(mobil)
# Out:
# 1.8

# %%
bantal=700
selimut=400
bantal%=motor
print(bantal)
# Out:
# 200

# %%
lampu=300
cahaya=900
lampu**=cahaya
print(lampu)
# Out:
# ...

# %%
tas=400
plastik=100
tas//=plastik
print(tas)
# Out:
# 4
